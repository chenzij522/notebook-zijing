# %% [markdown]
# # Set up (run it only once)

# %%
# !python -m venv .venv # creates the environment

# %% [markdown]
# Please activate the environment before to proceed

# %%
# %pip install scanpy anndata pandas scipy openpyxl pydeseq2 adjustText
# Out:
# Requirement already satisfied: scanpy in d:\anaconda2\lib\site-packages (1.12.1)
# Requirement already satisfied: anndata in d:\anaconda2\lib\site-packages (0.12.17)
# Requirement already satisfied: pandas in d:\anaconda2\lib\site-packages (2.3.3)
# Requirement already satisfied: scipy in d:\anaconda2\lib\site-packages (1.16.3)
# Requirement already satisfied: openpyxl in d:\anaconda2\lib\site-packages (3.1.5)
# Requirement already satisfied: pydeseq2 in d:\anaconda2\lib\site-packages (0.5.4)
# Requirement already satisfied: adjustText in d:\anaconda2\lib\site-packages (1.4.0)
# Requirement already satisfied: certifi in d:\anaconda2\lib\site-packages (from scanpy) (2025.11.12)
# Requirement already satisfied: fast-array-utils>=1.4 in d:\anaconda2\lib\site-packages (from fast-array-utils[accel,sparse]>=1.4->scanpy) (1.4.1)
# Requirement already satisfied: h5py>=3.11 in d:\anaconda2\lib\site-packages (from scanpy) (3.15.1)
# Requirement already satisfied: joblib in d:\anaconda2\lib\site-packages (from scanpy) (1.5.2)
# Requirement already satisfied: legacy-api-wrap>=1.5 in d:\anaconda2\lib\site-packages (from scanpy) (1.5)
# Requirement already satisfied: matplotlib>=3.9 in d:\anaconda2\lib\site-packages (from scanpy) (3.10.6)
# Requirement already satisfied: natsort in d:\anaconda2\lib\site-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.8.8 in d:\anaconda2\lib\site-packages (from scanpy) (3.5)
# Requirement already satisfied: numba>=0.60 in d:\anaconda2\lib\site-packages (from scanpy) (0.62.1)
# Requirement already satisfied: numpy>=2 in d:\anaconda2\lib\site-packages (from scanpy) (2.3.5)
# Requirement already satisfied: packaging>=25 in d:\anaconda2\lib\site-packages (from scanpy) (25.0)
# Requirement already satisfied: patsy in d:\anaconda2\lib\site-packages (from scanpy) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5.13 in d:\anaconda2\lib\site-packages (from scanpy) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.6 in d:\anaconda2\lib\site-packages (from scanpy) (1.7.2)
# Requirement already satisfied: seaborn>=0.13.2 in d:\anaconda2\lib\site-packages (from scanpy) (0.13.2)
# Requirement already satisfied: session-info2 in d:\anaconda2\lib\site-packages (from scanpy) (0.4.1)
# Requirement already satisfied: statsmodels>=0.14.5 in d:\anaconda2\lib\site-packages (from scanpy) (0.14.5)
# Requirement already satisfied: tqdm in d:\anaconda2\lib\site-packages (from scanpy) (4.67.1)
# Requirement already satisfied: umap-learn>=0.5.12 in d:\anaconda2\lib\site-packages (from scanpy) (0.5.12)
# Requirement already satisfied: array-api-compat>=1.7.1 in d:\anaconda2\lib\site-packages (from anndata) (1.15.0)
# Requirement already satisfied: scverse-misc>=0.0.3 in d:\anaconda2\lib\site-packages (from anndata) (0.0.9)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in d:\anaconda2\lib\site-packages (from anndata) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda2\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda2\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda2\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in d:\anaconda2\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: formulaic-contrasts>=0.2.0 in d:\anaconda2\lib\site-packages (from pydeseq2) (1.0.0)
# Requirement already satisfied: formulaic>=1.0.2 in d:\anaconda2\lib\site-packages (from pydeseq2) (1.2.2)
# Requirement already satisfied: interface-meta>=1.2.0 in d:\anaconda2\lib\site-packages (from formulaic>=1.0.2->pydeseq2) (2.0.1)
# Requirement already satisfied: narwhals>=1.17 in d:\anaconda2\lib\site-packages (from formulaic>=1.0.2->pydeseq2) (2.7.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in d:\anaconda2\lib\site-packages (from formulaic>=1.0.2->pydeseq2) (4.15.0)
# Requirement already satisfied: wrapt>=1.17.0rc1 in d:\anaconda2\lib\site-packages (from formulaic>=1.0.2->pydeseq2) (1.17.0)
# Requirement already satisfied: session-info in d:\anaconda2\lib\site-packages (from formulaic-contrasts>=0.2.0->pydeseq2) (1.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda2\lib\site-packages (from matplotlib>=3.9->scanpy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda2\lib\site-packages (from matplotlib>=3.9->scanpy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda2\lib\site-packages (from matplotlib>=3.9->scanpy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda2\lib\site-packages (from matplotlib>=3.9->scanpy) (1.4.9)
# Requirement already satisfied: pillow>=8 in d:\anaconda2\lib\site-packages (from matplotlib>=3.9->scanpy) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda2\lib\site-packages (from matplotlib>=3.9->scanpy) (3.2.5)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in d:\anaconda2\lib\site-packages (from numba>=0.60->scanpy) (0.45.1)
# Requirement already satisfied: six>=1.5 in d:\anaconda2\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda2\lib\site-packages (from scikit-learn>=1.6->scanpy) (3.5.0)
# Requirement already satisfied: donfig>=0.8 in d:\anaconda2\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in d:\anaconda2\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in d:\anaconda2\lib\site-packages (from zarr!=3.0.*,>=2.18.7->anndata) (0.16.5)
# Requirement already satisfied: pyyaml in d:\anaconda2\lib\site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata) (6.0.3)
# Requirement already satisfied: stdlib_list in d:\anaconda2\lib\site-packages (from session-info->formulaic-contrasts>=0.2.0->pydeseq2) (0.12.0)
# Requirement already satisfied: colorama in d:\anaconda2\lib\site-packages (from tqdm->scanpy) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib-venn
# Out:
# Requirement already satisfied: matplotlib-venn in d:\anaconda2\lib\site-packages (1.1.2)
# Requirement already satisfied: matplotlib in d:\anaconda2\lib\site-packages (from matplotlib-venn) (3.10.6)
# Requirement already satisfied: numpy in d:\anaconda2\lib\site-packages (from matplotlib-venn) (2.3.5)
# Requirement already satisfied: scipy in d:\anaconda2\lib\site-packages (from matplotlib-venn) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda2\lib\site-packages (from matplotlib->matplotlib-venn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda2\lib\site-packages (from matplotlib->matplotlib-venn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda2\lib\site-packages (from matplotlib->matplotlib-venn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda2\lib\site-packages (from matplotlib->matplotlib-venn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda2\lib\site-packages (from matplotlib->matplotlib-venn) (25.0)
# Requirement already satisfied: pillow>=8 in d:\anaconda2\lib\site-packages (from matplotlib->matplotlib-venn) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda2\lib\site-packages (from matplotlib->matplotlib-venn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda2\lib\site-packages (from matplotlib->matplotlib-venn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\anaconda2\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import scanpy as sc
import anndata as ad
from scipy import sparse
import os
import numpy as np
import matplotlib.pyplot as plt
import gc
from adjustText import adjust_text
from matplotlib_venn import venn2

# %% [markdown]
# # Single cell preprocessing pipeline

# %% [markdown]
# ## Data loading

# %%
file_path_FSHS1_1 = r"./data/GSM3487556_FSHD1.1.txt"
file_path_FSHS1_2 = r"./data/GSM3487557_FSHD1.2.txt"
file_path_FSHS2_1 = r"./data/GSM3487558_FSHD2.1.txt"
file_path_FSHS2_2 = r"./data/GSM3487559_FSHD2.2.txt"
file_path_ctrl1 = r"./data/GSM3487560_CTRL.1.txt"
file_path_ctrl2 = r"./data/GSM3487561_CTRL.2.txt"
file_path_DUX4_geneset = r"./data/DUX4_67_geneset.xlsx"
file_path_annotation = r"./data/annotation.gff3"

# %%
RNA_sequencing_data = [
    {"sample_name":"FSHD1.1",
     "file_path": file_path_FSHS1_1},
    {"sample_name":"FSHD1.2",
     "file_path": file_path_FSHS1_2},
    {"sample_name":"FSHD2.1",
     "file_path": file_path_FSHS2_1},
    {"sample_name":"FSHD2.2",
     "file_path": file_path_FSHS2_2},
    {"sample_name":"CTRL.1",
     "file_path": file_path_ctrl1},
    {"sample_name":"CTRL.2",
     "file_path": file_path_ctrl2},
]

# %% [markdown]
# ## Helper functions

# %%
def read_count_matrix(file_path, sample_name):
    # The read_count_matrix function is taking a file path and the sample name as input and returns the count matrix.

    counts = pd.read_csv(file_path, sep="\t", index_col=0)

    counts.index = counts.index.astype(str).str.replace('"', '', regex=False) # getting all gene names
    counts.columns = counts.columns.astype(str).str.replace('"', '', regex=False)  # getting all cell tags

    # Convert into the format required by Scanpy/Anndata: cells × genes (= transposing)
    counts = counts.T  # cells × genes (transpose)

    adata = ad.AnnData(
        X=sparse.csr_matrix(counts.values), # transcription matrix
        obs=pd.DataFrame(index=counts.index), # cells are treated as observations
        var=pd.DataFrame(index=counts.columns) # genes are treated as variables 
    )

    adata.obs["sample"] = sample_name
    adata.layers["counts"] = adata.X.copy()
    adata.var_names_make_unique() # makes gene names unique (e.g. multiple transcripts for the same gene)

    return adata

# %%
def remove_nan_genes(adata):
    # QC step: Remove genes that are not expressed
    # Convert X to dense array if needed
    X = adata.X.toarray() if sparse.issparse(adata.X) else adata.X
    
    # Keep genes without NaN or infinite values
    keep_genes = np.isfinite(X).all(axis=0)
    
    print("Genes before removing NaN genes:", adata.n_vars)
    print("Genes after removing NaN genes:", keep_genes.sum())
    
    return adata[:, keep_genes].copy()

# %%
def de_disease_group(adata, disease_name, de_layer="combat"):
    # performing a differential analysis based on disease phenotype (e.g. FSHD1, FSHD2 compared to controls)
    sub = adata[
        (adata.obs["disease_group"] == disease_name) &
        (adata.obs["cell_classification"].isin([
            "DUX4-affected",
            "Non-affected late myocytes"
        ]))
    ].copy()
    
    # Remove unused categories
    sub.obs["cell_classification"] = sub.obs["cell_classification"].astype("category")
    sub.obs["cell_classification"] = sub.obs["cell_classification"].cat.remove_unused_categories()
    
    # Count cells in each group
    group_counts = sub.obs["cell_classification"].value_counts()
    
    print("\nSample:", disease_name)
    print(group_counts)
    
    
    # Check minimum cell number
    if group_counts["DUX4-affected"] < 2:
        print("Skipped: DUX4-affected group has fewer than 2 cells.")
        return None
    
    if group_counts["Non-affected late myocytes"] < 2:
        print("Skipped: reference group has fewer than 2 cells.")
        return None
    
    # Run Wilcoxon differential expression analysis
    sc.tl.rank_genes_groups(
        sub,
        groupby="cell_classification",
        groups=["DUX4-affected"],
        reference="Non-affected late myocytes",
        method="wilcoxon",
        corr_method="benjamini-hochberg",
        use_raw=False
    )
    
    # Convert result to dataframe
    de_df = sc.get.rank_genes_groups_df(
        sub,
        group="DUX4-affected"
    )
    
    de_df = de_df.rename(columns={"names": "gene_id"})
    de_df["disease_group"] = disease_name
    
    return de_df

# %%
def run_de_for_sample(adata, sample_name):
    sub = adata[
        (adata.obs["sample_batch"] == sample_name) &
        (adata.obs["cell_classification"].isin([
            "DUX4-affected",
            "Non-affected late myocytes"
        ]))
    ].copy()
    
    # Remove unused categories
    sub.obs["cell_classification"] = sub.obs["cell_classification"].astype("category")
    sub.obs["cell_classification"] = sub.obs["cell_classification"].cat.remove_unused_categories()
    
    # Count cells in each group
    group_counts = sub.obs["cell_classification"].value_counts()
    
    print("\nSample:", sample_name)
    print(group_counts)
    
    
    # Check minimum cell number
    if group_counts["DUX4-affected"] < 2:
        print("Skipped: DUX4-affected group has fewer than 2 cells.")
        return None
    
    if group_counts["Non-affected late myocytes"] < 2:
        print("Skipped: reference group has fewer than 2 cells.")
        return None
    
    # Run Wilcoxon differential expression analysis
    sc.tl.rank_genes_groups(
        sub,
        groupby="cell_classification",
        groups=["DUX4-affected"],
        reference="Non-affected late myocytes",
        method="wilcoxon",
        corr_method="benjamini-hochberg",
        use_raw=False
    )
    
    # Convert result to dataframe
    de_df = sc.get.rank_genes_groups_df(
        sub,
        group="DUX4-affected"
    )
    
    de_df = de_df.rename(columns={"names": "gene_id"})
    de_df["sample"] = sample_name
    
    return de_df

# %%
# GFF3 standard column names
gff_cols = [
    "seqid", "source", "type", "start", "end",
    "score", "strand", "phase", "attributes"
]

# Read GFF3 file and skip comment lines
gff = pd.read_csv(
    file_path_annotation,
    sep="\t",
    comment="#",
    header=None,
    names=gff_cols,
    engine="python"
)

# Keep only gene-level annotation
genes = gff[gff["type"] == "gene"].copy()

# Extract Ensembl gene ID and gene symbol
genes["gene_id"] = genes["attributes"].str.extract(r"(?:^|;)gene_id=([^;]+)")
genes["gene_name"] = genes["attributes"].str.extract(r"(?:^|;)gene_name=([^;]+)")

# Clean Ensembl ID: remove version number
genes["gene_id_clean"] = (
    genes["gene_id"]
    .astype(str)
    .str.strip()
    .str.replace(r"\.\d+$", "", regex=True)
)

# Build annotation table
annotation = (
    genes[["gene_id_clean", "gene_name"]]
    .dropna()
    .drop_duplicates()
)

# Create mapping dictionary: clean Ensembl ID -> gene symbol
id_to_symbol = dict(zip(annotation["gene_id_clean"], annotation["gene_name"]))

# %%
def annotate_gene_set(gene_set, id_to_symbol, gene_set_name):
    df = pd.DataFrame({
        "ensembl_id": sorted(list(gene_set))
    })
    
    df["ensembl_id_clean"] = (
        df["ensembl_id"]
        .astype(str)
        .str.strip()
        .str.replace(r"\.\d+$", "", regex=True)
    )
    
    df["gene_symbol"] = df["ensembl_id_clean"].map(id_to_symbol)
    df.insert(0, "gene_set", gene_set_name)
    
    return df

# %%
# function for volcano plot
def plot_volcano(
    de_df,
    title,
    gene_col="gene_symbol",
    logfc_col="logfoldchanges",
    padj_col="pvals_adj",
    padj_cutoff=0.05,
    logfc_cutoff=1,
    label_top=10,
    xlim=(-15, 15)
    ):
    df = de_df.copy()
    
    # Remove missing or infinite values
    df = df.replace([np.inf, -np.inf], np.nan)
    df = df.dropna(subset=[logfc_col, padj_col])
    
    # Avoid -log10(0)
    df[padj_col] = df[padj_col].replace(0, 1e-300)
    
    # Calculate -log10 adjusted p-value
    df["minus_log10_padj"] = -np.log10(df[padj_col])
    
    # Define volcano groups
    df["volcano_group"] = "Not significant"
    
    df.loc[
        (df[padj_col] < padj_cutoff) &
        (df[logfc_col] > logfc_cutoff),
        "volcano_group"] = "Upregulated"
    
    df.loc[
        (df[padj_col] < padj_cutoff) &
        (df[logfc_col] < -logfc_cutoff),
        "volcano_group"] = "Downregulated"
    
    plt.figure(figsize=(7, 5))
    
    # Not significant genes
    plt.scatter(
        df.loc[df["volcano_group"] == "Not significant", logfc_col],
        df.loc[df["volcano_group"] == "Not significant", "minus_log10_padj"],
        s=8,
        alpha=0.4,
        color="black",
        label="Not significant")
    
    # Downregulated genes
    plt.scatter(
        df.loc[df["volcano_group"] == "Downregulated", logfc_col],
        df.loc[df["volcano_group"] == "Downregulated", "minus_log10_padj"],
        s=12,
        alpha=0.8,
        color="blue",
        label="Downregulated")
    
    # Upregulated genes
    plt.scatter(
        df.loc[df["volcano_group"] == "Upregulated", logfc_col],
        df.loc[df["volcano_group"] == "Upregulated", "minus_log10_padj"],
        s=12,
        alpha=0.8,
        color="red",
        label="Upregulated")
    
    # Cutoff lines
    y_cutoff = -np.log10(padj_cutoff)
    
    plt.axhline(
        y_cutoff,
        linestyle="--",
        linewidth=1,
        color="black")
    
    plt.axvline(
        logfc_cutoff,
        linestyle="--",
        linewidth=1,
        color="black")
    
    plt.axvline(
        -logfc_cutoff,
        linestyle="--",
        linewidth=1,
        color="black")
    
    # Add cutoff labels
    plt.text(
        x=xlim[0] + 0.5,
        y=y_cutoff + 0.05,
        s="BH adjusted p-value < 0.05",
        fontsize=8,
        va="bottom",
        ha="left")
    
    plt.text(
        x=logfc_cutoff + 0.1,
        y=0.1,
        s="log2FC > 1",
        fontsize=8,
        va="bottom",
        ha="left")
    
    plt.text(
        x=-logfc_cutoff - 0.1,
        y=0.1,
        s="log2FC < -1",
        fontsize=8,
        va="bottom",
        ha="right")
    
    # Label top significant genes
    top_genes = (
        df[df["volcano_group"].isin(["Upregulated", "Downregulated"])]
        .sort_values(padj_col)
        .head(label_top))
    
    texts = []

    for _, row in top_genes.iterrows():
        texts.append(
        plt.text(
            row[logfc_col],
            row["minus_log10_padj"],
            str(row[gene_col]),
            fontsize=8))

    adjust_text(
    texts,
    arrowprops=dict(
        arrowstyle="-",
        color="gray",
        lw=0.5))
    
    # Set x-axis range
    plt.xlim(xlim)

    plt.xlabel("log2 fold change")
    plt.ylabel("-log10 adjusted p-value (BH corrected)")
    plt.title(title)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Create adata and merge samples

# %%
adata_list = []
sample_names = []
for my_sample_RNA_seq in RNA_sequencing_data:
    adata_list = adata_list + [read_count_matrix(my_sample_RNA_seq["file_path"], my_sample_RNA_seq["sample_name"])]
    sample_names = sample_names + [my_sample_RNA_seq["sample_name"]]

# %%
# merge all samples into one anndata object, with sample names as batch labels
adata = ad.concat(
    adata_list,
    label = "sample_batch",
    keys = sample_names,
    join = "outer",
    index_unique = "-",
    fill_value=0
)

print(adata)
adata.write_h5ad("./data/combined_raw_counts.h5ad")
# Out:
# AnnData object with n_obs × n_vars = 7047 × 33694
#     obs: 'sample', 'sample_batch'
#     layers: 'counts'

# %% [markdown]
# ## QC

# %% [markdown]
# ### Violin diagrams

# %%
# load the combined anndata object
adata = sc.read_h5ad("./data/combined_raw_counts.h5ad")

# ensure cell names / gene names are unique
adata.obs_names_make_unique()
adata.var_names_make_unique()

sc.pp.calculate_qc_metrics(
    adata,
    inplace=True
)

adata.obs["total counts per cell"] = adata.obs["total_counts"]
adata.obs["number of genes expressed per cell"] = adata.obs["n_genes_by_counts"]

adata.obs.groupby("sample_batch")[["total counts per cell", "number of genes expressed per cell"]].describe()
sc.pl.violin(
    adata,
    ["total counts per cell", "number of genes expressed per cell"],
    groupby="sample_batch",
    jitter=0.4,
    multi_panel=True
)
# Out:
# C:\Users\Tanya\AppData\Local\Temp\ipykernel_51136\3666608941.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   adata.obs.groupby("sample_batch")[["total counts per cell", "number of genes expressed per cell"]].describe()

# %% [markdown]
# We produced 2 graphs: (1) the total number of counts per sample, (2) the total of expressed genes by counts.
# Observations:
# (1) there seems to be signifant differences of total counts between samples (e.g. the average count is significantly different between FSHD1.1 and CTRL.2). The violin plots are not testing how significant that is. The conclusion is that there seems to be a significant effect of the batch. **That means that we should correct for the batch effect.**
# (2) same idea for 2. The conclusion is that there seems to be a significant effect of the total of number of expressed genes by counts. **The total number of expressed genes by count should be also accounted for in the model specification.**

# %% [markdown]
# Using the violin plot observations we decided to calculate the factors that affect the expression measured: the total counts and number of genes per cell. We evaluate the different quantiles for each factor.

# %%
# Summarize QC metrics by sample
qc_summary = (
    adata.obs
    .groupby("sample_batch", observed=True)[["total_counts", "n_genes_by_counts"]]
    .quantile([0.01, 0.05,0.1,0.25, 0.50, 0.75,0.9, 0.95, 1])
)

qc_summary
# Out:
#                    total_counts  n_genes_by_counts
# sample_batch
# FSHD1.1      0.01       3630.68             679.16
#              0.05       4479.60             918.40
#              0.10       5486.60            1152.00
#              0.25       7920.00            1709.00
#              0.50      11297.00            2175.00
#              0.75      15975.00            2762.00
#              0.90      21794.00            3241.60
#              0.95      26536.60            3539.40
#              1.00      55108.00            5462.00
# FSHD1.2      0.01       2705.93             802.41
#              0.05       4023.05            1246.20
#              0.10       5233.70            1603.70
#              0.25       7847.50            2061.50
#              0.50      10208.50            2399.00
#              0.75      13045.75            2797.00
#              0.90      16021.80            3151.50
#              0.95      18128.75            3470.05
#              1.00      48143.00            5315.00
# FSHD2.1      0.01       1876.44             543.61
#              0.05       2541.45             759.70
#              0.10       3230.90             997.20
#              0.25       5201.75            1489.75
#              0.50       7557.00            1932.50
#              0.75      10225.25            2331.75
#              0.90      13247.80            2707.30
#              0.95      15082.50            2890.95
#              1.00      38623.00            4599.00
# FSHD2.2      0.01       2255.33             551.18
#              0.05       2854.05             778.40
#              0.10       4050.30            1010.50
#              0.25       8144.75            2001.00
#              0.50      11797.00            2567.50
#              0.75      15195.50            2964.75
#              0.90      18562.10            3244.50
#              0.95      20935.80            3456.90
#              1.00      44700.00            5508.00
# CTRL.1       0.01       1483.84             644.44
#              0.05       2673.60             937.00
#              0.10       3890.40            1296.20
#              0.25       5644.00            1712.00
#              0.50       7431.00            2036.00
#              0.75       9541.00            2358.00
#              0.90      11778.60            2636.20
#              0.95      12933.20            2790.00
#              1.00      25318.00            4058.00
# CTRL.2       0.01       1021.00             461.00
#              0.05       1637.00             744.00
#              0.10       2169.00             898.00
#              0.25       2986.00            1156.00
#              0.50       4217.00            1504.00
#              0.75       5516.00            1799.00
#              0.90       6732.00            2022.00
#              0.95       7847.00            2163.00
#              1.00      19481.00            3669.00

# %% [markdown]
# The total expression is variable between batches because the total counts we observe while sequencing is dependent on the amplification that was performed for each sample. It seems that the amplification was much smaller for CTRL2 than for the remaining samples. If we take a QC filtering common for all samples, that may create significantly unbalanced classes of deseases that will affect downstream the statistics. We propose to filter the cells that are below 5% of the total counts for at least one of the two factors.

# %% [markdown]
# ### Correlation between number of genes and counts per cell before QC

# %%
# correlation between number of genes and  counts
samples = adata.obs["sample_batch"].unique()
# correlation between number of genes and total counts
plt.figure(figsize=(7, 5))

for sample in samples:
    sub = adata.obs[adata.obs["sample_batch"] == sample]
    plt.scatter(
        sub["total_counts"],
        sub["n_genes_by_counts"],
        s=5,
        alpha=0.4,
        label=sample
    )

plt.xlabel("Total counts per cell")
plt.ylabel("Number of genes per cell")
plt.legend(markerscale=3, bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()

corr_by_sample = (
    adata.obs
    .groupby("sample_batch", observed=True)
    .apply(lambda x: x["total_counts"].corr(x["n_genes_by_counts"], method="spearman"))
)

corr_by_sample
# Out:
# C:\Users\Tanya\AppData\Local\Temp\ipykernel_51136\1237921823.py:25: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x["total_counts"].corr(x["n_genes_by_counts"], method="spearman"))
# sample_batch
# FSHD1.1    0.904163
# FSHD1.2    0.959738
# FSHD2.1    0.967815
# FSHD2.2    0.947967
# CTRL.1     0.973387
# CTRL.2     0.970566
# dtype: float64

# %% [markdown]
# It seems that we have cell outliers in FSHD1.1 sample. Those are likely under-sequenced cells that we need to remove.

# %% [markdown]
# ## QC correlation with thresholds

# %%
# Define thresholds
gene_thresholds = {
    "FSHD1.1": 679,
    "FSHD1.2": 802,
    "FSHD2.1": 544,
    "FSHD2.2": 551,
    "CTRL.1": 644,
    "CTRL.2": 461}

count_thresholds = {
    "FSHD1.1": (4480, 45000),
    "FSHD1.2": (4023, 30000),
    "FSHD2.1": (2541, 27000),
    "FSHD2.2": (2854, 30000),
    "CTRL.1": (2674, 18000),
    "CTRL.2": (1637, 15000)}



sample_order = ["FSHD1.1", "FSHD1.2", "FSHD2.1","FSHD2.2", "CTRL.1", "CTRL.2"]

# Keep only samples that exist in adata
sample_order = [
    s for s in sample_order
    if s in adata.obs["sample_batch"].astype(str).unique()]

# Create subplots
fig, axes = plt.subplots(
    2, 3,
    figsize=(13, 8),
    sharex=False,
    sharey=False)

axes = axes.flatten()

for ax, sample in zip(axes, sample_order):
    sub = adata.obs[
        adata.obs["sample_batch"].astype(str) == sample]
    
    x_low, x_high = count_thresholds[sample]
    y_low = gene_thresholds[sample]
    
    # Scatter plot
    ax.scatter(
        sub["total_counts"],
        sub["n_genes_by_counts"],
        s=5,
        alpha=0.4)
    
    # Add total_counts thresholds
    ax.axvline(
        x=x_low,
        linestyle="--",
        linewidth=1,
        color="black",
        label="count threshold")
    
    ax.axvline(
        x=x_high,
        linestyle="--",
        linewidth=1,
        color="black")
    
    # Add detected genes threshold
    ax.axhline(
        y=y_low,
        linestyle="--",
        linewidth=1,
        color="royalblue",
        label="gene threshold")
    
    ax.set_title(sample)
    ax.set_xlabel("Total counts per cell")
    ax.set_ylabel("Detected genes per cell")
    
    # show threshold values
    ax.text(
        x=x_low * 1.2,
        y=ax.get_ylim()[1] * 0.95,
        s=str(x_low),
        color="black",
        fontsize=8,
        rotation=90,
        va="top")
    
    ax.text(
        x=x_high * 1.05,
        y=ax.get_ylim()[1] * 0.95,
        s=str(x_high),
        color="black",
        fontsize=8,
        rotation=90,
        va="top"
    )
    
    ax.text(
        x=ax.get_xlim()[1] * 0.65,
        y=y_low,
        s=f"genes={y_low}",
        color="royalblue",
        fontsize=8,
        va="bottom"
    )

# Hide unused subplots if any
for ax in axes[len(sample_order):]:
    ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### QC implementation

# %% [markdown]
# Based of the observations on the factors distributions, let's implement a filtering to make sure we keep only good quality sequenced cells. In the publication associated with the data, the authors did not tell what filtering criteria was used. Therefore, we cannot reproduce this step to replicate the data analysis of the publication. The only information found was in Figure S2 but the actual numbers used for filteing were not reported. This demonstrate how important the full description of the parameters choices made during the analysis pipelines is important to share and follow Findable Accessible Interoperable and Reproducible (FAIR) principles.
# For the follow up analysis, we parametrized the filtering criteria to match the total cumber of filtered cells as reported in the publication.

# %%
# Make a copy before filtering
adata_qc = adata.copy()

# Calculate QC metrics
sc.pp.calculate_qc_metrics(adata_qc, inplace=True)

# Calculate sample-specific 5% thresholds
adata_qc.obs["min_genes_1pct"] = (
    adata_qc.obs
    .groupby("sample_batch")["n_genes_by_counts"]
    .transform(lambda x: x.quantile(0.01)))

adata_qc.obs["min_counts_5pct"] = (
    adata_qc.obs
    .groupby("sample_batch")["total_counts"]
    .transform(lambda x: x.quantile(0.05)))

# Mark cells above the 5% QC thresholds
adata_qc.obs["keep_above_5pct"] = (
    (adata_qc.obs["n_genes_by_counts"] >= adata_qc.obs["min_genes_1pct"]) &
    (adata_qc.obs["total_counts"] >= adata_qc.obs["min_counts_5pct"]))

# Define sample-specific total_counts ranges based on the observed distributions 
count_ranges = {
    "FSHD1.1": (1000, 45000),
    "FSHD1.2": (1000, 30000),
    "FSHD2.1": (1000, 27000),
    "FSHD2.2": (1000, 30000),
    "CTRL.1": (1000, 18000),
    "CTRL.2": (1000, 15000)}

adata_qc.obs["min_counts_sample"] = adata_qc.obs["sample_batch"].map(
    lambda x: count_ranges[str(x)][0])

adata_qc.obs["max_counts_sample"] = adata_qc.obs["sample_batch"].map(
    lambda x: count_ranges[str(x)][1])

# Mark cells within sample-specific total_counts range
adata_qc.obs["keep_counts_range"] = (
    (adata_qc.obs["total_counts"] >= adata_qc.obs["min_counts_sample"]) &
    (adata_qc.obs["total_counts"] <= adata_qc.obs["max_counts_sample"]))

# Final QC filter
adata_qc.obs["keep_cell"] = (
    adata_qc.obs["keep_above_5pct"] &
    adata_qc.obs["keep_counts_range"])

# Check filtering result per sample
print(pd.crosstab(
    adata_qc.obs["sample_batch"],
    adata_qc.obs["keep_cell"]))

# Apply filtering
adata_qc = adata_qc[
    adata_qc.obs["keep_cell"],
    :].copy()

# Remove genes not expressed in any remaining cells
sc.pp.filter_genes(adata_qc, min_cells=1)

print("Before filtering:", adata.n_obs, "cells")
print("After filtering:", adata_qc.n_obs, "cells")
# Out:
# C:\Users\Tanya\AppData\Local\Temp\ipykernel_51136\10268049.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby("sample_batch")["n_genes_by_counts"]
# C:\Users\Tanya\AppData\Local\Temp\ipykernel_51136\10268049.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby("sample_batch")["total_counts"]
# keep_cell     False  True
# sample_batch
# FSHD1.1         126   2119
# FSHD1.2          51    837
# FSHD2.1          72   1216
# FSHD2.2          42    670
# CTRL.1           46    767
# CTRL.2           62   1039
# Before filtering: 7047 cells
# After filtering: 6648 cells

# %% [markdown]
# # counts/genes correlation per cell after qc

# %%
# correlation between number of genes and  counts
samples = adata_qc.obs["sample_batch"].unique()
# correlation between number of genes and total counts
plt.figure(figsize=(7, 5))

for sample in samples:
    sub = adata_qc.obs[adata_qc.obs["sample_batch"] == sample]
    plt.scatter(
        sub["total_counts"],
        sub["n_genes_by_counts"],
        s=5,
        alpha=0.4,
        label=sample
    )

plt.xlabel("Total counts per cell")
plt.ylabel("Number of genes per cell")
plt.legend(markerscale=3, bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xlim(0, 55000)
plt.ylim(0, 5500)
plt.tight_layout()
plt.show()

corr_by_sample = (
    adata_qc.obs
    .groupby("sample_batch", observed=True)
    .apply(lambda x: x["total_counts"].corr(x["n_genes_by_counts"], method="spearman"))
)

corr_by_sample
# Out:
# C:\Users\Tanya\AppData\Local\Temp\ipykernel_85776\1432234074.py:27: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x["total_counts"].corr(x["n_genes_by_counts"], method="spearman"))
# sample_batch
# FSHD1.1    0.890031
# FSHD1.2    0.952171
# FSHD2.1    0.963055
# FSHD2.2    0.938559
# CTRL.1     0.968421
# CTRL.2     0.965217
# dtype: float64

# %%
after_qc_summary = (
    adata_qc.obs
    .groupby("sample_batch", observed=True)[["total_counts", "n_genes_by_counts"]]
    .quantile([0.01, 0.05,0.1,0.25, 0.50, 0.75,0.9, 0.95, 1])
)

after_qc_summary
# Out:
#                    total_counts  n_genes_by_counts
# sample_batch
# FSHD1.1      0.01       4683.08             769.00
#              0.05       5469.00            1077.50
#              0.10       6476.40            1360.60
#              0.25       8354.50            1790.00
#              0.50      11697.00            2220.00
#              0.75      16266.50            2785.50
#              0.90      21922.20            3249.20
#              0.95      26263.80            3534.30
#              1.00      43751.00            4769.00
# FSHD1.2      0.01       4268.64            1274.44
#              0.05       5225.00            1603.00
#              0.10       6225.60            1785.60
#              0.25       8211.00            2130.00
#              0.50      10489.00            2440.00
#              0.75      13123.00            2806.00
#              0.90      16023.40            3152.00
#              0.95      18056.20            3452.00
#              1.00      29175.00            4342.00
# FSHD2.1      0.01       2694.25             690.45
#              0.05       3232.25             986.50
#              0.10       3939.00            1223.00
#              0.25       5565.50            1581.00
#              0.50       7858.00            1974.00
#              0.75      10401.50            2366.50
#              0.90      13346.00            2719.50
#              0.95      15166.25            2892.00
#              1.00      25175.00            3826.00
# FSHD2.2      0.01       3051.18             723.94
#              0.05       4102.95            1012.25
#              0.10       5716.50            1400.30
#              0.25       8948.75            2112.50
#              0.50      12258.00            2611.00
#              0.75      15384.00            2972.75
#              0.90      18606.40            3248.50
#              0.95      20930.85            3456.00
#              1.00      29751.00            4124.00
# CTRL.1       0.01       2963.38             980.14
#              0.05       3883.80            1291.50
#              0.10       4632.80            1484.20
#              0.25       6036.00            1762.00
#              0.50       7656.00            2065.00
#              0.75       9608.00            2366.50
#              0.90      11792.20            2638.40
#              0.95      12802.90            2781.90
#              1.00      17774.00            3389.00
# CTRL.2       0.01       1723.76             748.94
#              0.05       2150.90             886.90
#              0.10       2447.00             986.80
#              0.25       3172.50            1219.50
#              0.50       4316.00            1523.00
#              0.75       5584.00            1812.50
#              0.90       6732.60            2022.60
#              0.95       7796.30            2150.40
#              1.00      14717.00            2990.00
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # normalization

# %%
# copy for normalization
adata_norm = adata_qc.copy()

# Store raw counts before normalization
adata_norm.layers["counts"] = adata_norm.X.copy()

# Normalize each cell to the same total count
sc.pp.normalize_total(
    adata_norm,
    target_sum=1e4
)

# Log-transform the normalized data
sc.pp.log1p(adata_norm)

# Store log-normalized data
adata_norm.layers["lognorm"] = adata_norm.X.copy()

adata_norm.write_h5ad("combined_qc_normalized.h5ad")

# %% [markdown]
# # load DUX4-67 gene set

# %%
# Add Ensembl ID column from adata gene names
adata_norm.var["ensembl_id"] = (
    adata_norm.var_names
    .astype(str)
    .str.replace('"', '', regex=False)
    .str.strip()
    .str.replace(r"\.\d+$", "", regex=True)
)

# %%
# Read file: DUX4 67 gene set
dux4_df = pd.read_excel(file_path_DUX4_geneset,header=1,engine="openpyxl")

# Extract Ensembl id from the DUX4-67 gene set
dux4_67_ensg = (
    dux4_df["ENSEMBL"]
    .dropna()
    .astype(str)
    .str.strip()
    .str.replace(r"\.\d+$", "", regex=True)  # remove version number if present
    .unique()
    .tolist()
)

# Find DUX4-67 genes present in target dataset
dux4_genes_present = [
    gene for gene in dux4_67_ensg
    if gene in set(adata_norm.var["ensembl_id"])
]

print("DUX4-67 genes in file:", len(dux4_67_ensg))
print("DUX4-67 genes found in adata:", len(dux4_genes_present))
# Out:
# DUX4-67 genes in file: 67
# DUX4-67 genes found in adata: 36

# %% [markdown]
# # cell classification

# %%
#caculate the number of biomakers expresseed by cells
X_counts = adata_norm.layers["counts"]

# Get gene indices of DUX4-67 genes
dux4_gene_idx = np.where(
    adata_norm.var["ensembl_id"].isin(dux4_genes_present)
)[0]

# Extract raw counts of DUX4-67 genes
dux4_counts = X_counts[:, dux4_gene_idx]

# Count how many DUX4 biomarkers are expressed in each cell
if sparse.issparse(dux4_counts):
    adata_norm.obs["n_DUX4_targets_expressed"] = np.asarray(
        (dux4_counts > 0).sum(axis=1)
    ).ravel()
else:
    adata_norm.obs["n_DUX4_targets_expressed"] = (dux4_counts > 0).sum(axis=1)

adata_norm.obs["n_DUX4_targets_expressed"].describe()
# Out:
# count    6648.000000
# mean        0.181558
# std         1.028835
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        29.000000
# Name: n_DUX4_targets_expressed, dtype: float64

# %%
# Define DUX4-affected cells
adata_norm.obs["DUX4_affected"] = adata_norm.obs["n_DUX4_targets_expressed"] >= 5
adata_norm.obs["DUX4_affected"].value_counts()

# caculate counts of MYH3
myh3_ensg = "ENSG00000109063"

myh3_idx = np.where(adata_norm.var["ensembl_id"] == myh3_ensg)[0]

if len(myh3_idx) == 0:
    raise ValueError("MYH3 Ensembl ID was not found in adata.")

myh3_counts = X_counts[:, myh3_idx[0]]

if sparse.issparse(myh3_counts):
    myh3_counts = np.asarray(myh3_counts.todense()).ravel()
else:
    myh3_counts = np.asarray(myh3_counts).ravel()

adata_norm.obs["MYH3_counts"] = myh3_counts

# %%
# > 1 read 
if sparse.issparse(dux4_counts):
    adata_norm.obs["n_DUX4_targets_expressed"] = np.asarray(
        (dux4_counts > 0).sum(axis=1)
    ).ravel()
else:
    adata_norm.obs["n_DUX4_targets_expressed"] = (
        dux4_counts > 0
    ).sum(axis=1)


# Initialize all cells as Other
adata_norm.obs["cell_classification"] = "Other"

# DUX4-affected cells:
# Cells expressing at least 5 DUX4-67 biomarkers
# Each biomarker is counted as expressed if raw count >= 1 read
adata_norm.obs.loc[
    adata_norm.obs["n_DUX4_targets_expressed"] >= 5,
    "cell_classification"
] = "DUX4-affected"

# Non-affected late myocytes:
# Cells with MYH3 raw counts >= 5
# and fewer than 5 expressed DUX4-67 biomarkers
adata_norm.obs.loc[
    (adata_norm.obs["MYH3_counts"] >= 5) &
    (adata_norm.obs["n_DUX4_targets_expressed"] < 5),
    "cell_classification"
] = "Non-affected late myocytes"


# Total number of cells in the current AnnData object
print("Total cell count:", adata_norm.n_obs)

# Count cells in each classification group
print(adata_norm.obs["cell_classification"].value_counts())
# Out:
# Total cell count: 6648
# cell_classification
# Other                         3453
# Non-affected late myocytes    3168
# DUX4-affected                   27
# Name: count, dtype: int64

# %%
# Check cell classification numbers
classification_summary = pd.crosstab(
    adata_norm.obs["sample_batch"],
    adata_norm.obs["cell_classification"]
)

classification_summary
# Out:
# cell_classification  DUX4-affected  Non-affected late myocytes  Other
# sample_batch
# FSHD1.1                         12                         725   1382
# FSHD1.2                          2                         501    334
# FSHD2.1                         11                         569    636
# FSHD2.2                          2                         354    314
# CTRL.1                           0                         495    272
# CTRL.2                           0                         524    515

# %% [markdown]
# # correction

# %% [markdown]
# # combat correction

# %%
gc.collect()
# Out:
# 168131

# %%
# Make a copy for ComBat analysis
adata_combat = adata_norm.copy()

# Use log-normalized data
adata_combat.X = adata_combat.layers["lognorm"].copy()

# Run ComBat
sc.pp.combat(
    adata_combat,
    key="sample_batch"
)

adata_combat.obs["cell_classification"] = adata_norm.obs.loc[
    adata_combat.obs_names,
    "cell_classification"].values

# Remove genes with NaN after ComBat
adata_combat = remove_nan_genes(adata_combat)

# Save ComBat-corrected data
adata_combat.layers["combat"] = adata_combat.X.copy()
# Out:
# d:\anaconda\envs\Phelma1\lib\site-packages\scanpy\preprocessing\_combat.py:344: RuntimeWarning: divide by zero encountered in divide
#   (abs(g_new - g_old) / g_old).max(), (abs(d_new - d_old) / d_old).max()
# Genes before removing NaN genes: 21460
# Genes after removing NaN genes: 21460

# %% [markdown]
# # PCA diagram (before combat and after combat)

# %%
# select HVG （only DUX4 affected and non-affected cells)

# Subset DUX4-affected cells and non-affected late myocytes
adata_subset_before = adata_norm[
    adata_norm.obs["cell_classification"].isin([
        "DUX4-affected",
        "Non-affected late myocytes"
    ])
].copy()

# Use log-normalized data for HVG selection
adata_subset_before.X = adata_subset_before.layers["lognorm"].copy()

# Select highly variable genes on log-normalized data
sc.pp.highly_variable_genes(
    adata_subset_before,
    n_top_genes=2000,
    flavor="seurat"
)

# Save the same HVGs for before and after ComBat PCA
hvg_genes_subset = adata_subset_before.var_names[
    adata_subset_before.var["highly_variable"]
]
  
# PCA before ComBat correction
adata_pca_subset_before = adata_subset_before[:, hvg_genes_subset].copy()

# Use log-normalized data
adata_pca_subset_before.X = adata_pca_subset_before.layers["lognorm"].copy()

# Scale and run PCA
sc.pp.scale(adata_pca_subset_before, max_value=10)
sc.tl.pca(adata_pca_subset_before, svd_solver="arpack")

# PCA colored by cell classification
sc.pl.pca(
    adata_pca_subset_before,
    color="cell_classification",
    title="Subset PCA before ComBat: cell classification"
)

# PCA colored by sample
sc.pl.pca(
    adata_pca_subset_before,
    color="sample_batch",
    title="Subset PCA before ComBat: sample batch"
)
# Out:
# d:\anaconda\envs\Phelma1\lib\functools.py:889: UserWarning: zero-centering a sparse array/matrix densifies it.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
# PCA after combat(using same HVG as before)

# Subset the ComBat-corrected object
adata_pca_subset_after = adata_combat[
    adata_combat.obs["cell_classification"].isin([
        "DUX4-affected",
        "Non-affected late myocytes"
    ])
].copy()

# Use the same HVGs as before
adata_pca_subset_after = adata_pca_subset_after[:, hvg_genes_subset].copy()

# Use ComBat-corrected data
adata_pca_subset_after.X = adata_pca_subset_after.layers["combat"].copy()

# Scale and run PCA
sc.pp.scale(adata_pca_subset_after, max_value=10)
sc.tl.pca(adata_pca_subset_after, svd_solver="arpack")

# PCA colored by cell classification
sc.pl.pca(
    adata_pca_subset_after,
    color="cell_classification",
    title="Subset PCA after ComBat: cell classification"
)

# PCA colored by sample
sc.pl.pca(
    adata_pca_subset_after,
    color="sample_batch",
    title="Subset PCA after ComBat: sample batch"
)

# %% [markdown]
# # optional: PCA before/after combat correction (other cells included)

# %%
# PCA before batch correction (other cells included)
adata_pca_before = adata_combat.copy()

# Use log-normalized data
adata_pca_before.X = adata_pca_before.layers["lognorm"].copy()

# Select highly variable genes
sc.pp.highly_variable_genes(
    adata_pca_before,
    n_top_genes=2000,
    flavor="seurat"
)

# Keep only highly variable genes
adata_pca_before = adata_pca_before[:, adata_pca_before.var["highly_variable"]].copy()

# Scale data before PCA
sc.pp.scale(
    adata_pca_before,
    max_value=10
)

# Run PCA
sc.tl.pca(
    adata_pca_before,
    svd_solver="arpack"
)

# Plot PCA colored by sample
sc.pl.pca(
    adata_pca_before,
    color="sample_batch",
    title="PCA before batch correction"
)

# Plot PCA colored by cell classification
sc.pl.pca(
    adata_pca_before,
    color="cell_classification",
    title="PCA before batch correction"
)

# %%
# PCA after ComBat correction(other cells included)
adata_pca_after = adata_combat.copy()

# Use ComBat-corrected data
adata_pca_after.X = adata_pca_after.layers["combat"].copy()

# Use the same highly variable genes as before
hvg_genes = adata_pca_before.var_names

adata_pca_after = adata_pca_after[:, hvg_genes].copy()

# Scale data before PCA
sc.pp.scale(
    adata_pca_after,
    max_value=10
)

# Run PCA
sc.tl.pca(
    adata_pca_after,
    svd_solver="arpack"
)

# Plot PCA colored by sample
sc.pl.pca(
    adata_pca_after,
    color="sample_batch",
    title="PCA after ComBat correction"
)

# Plot PCA colored by cell classification
sc.pl.pca(
    adata_pca_after,
    color="cell_classification",
    title="PCA after ComBat correction"
)

# %% [markdown]
# # differential analysis using disease group

# %%
# Use batch effect removed data for differential expression
adata_de = adata_combat.copy()

# Use ComBat-corrected data
adata_de.X = adata_de.layers["combat"].copy()

# %%
# Define disease_group = FSHD1 / FSHD2 / Control
group_map = {
    "FSHD1.1": "FSHD1",
    "FSHD1.2": "FSHD1",
    "FSHD2.1": "FSHD2",
    "FSHD2.2": "FSHD2",
    "CTR1": "Control",
    "CTR2": "Control"}

adata_de.obs["disease_group"] = (
    adata_de.obs["sample_batch"]
    .astype(str)
    .map(group_map))

# %%
# DE results
disease_groups = ["FSHD1", "FSHD2"]

de_results = []

for disease in disease_groups:
    result = de_disease_group(
        adata_de,
        disease_name= disease,
        de_layer="combat"
    )
    
    if result is not None:
        de_results.append(result)

de_by_disease = pd.concat(de_results, ignore_index=True)
# Out:
# Sample: FSHD1
# cell_classification
# Non-affected late myocytes    1226
# DUX4-affected                   14
# Name: count, dtype: int64
# d:\anaconda\envs\Phelma1\lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(
# Sample: FSHD2
# cell_classification
# Non-affected late myocytes    923
# DUX4-affected                  13
# Name: count, dtype: int64
# d:\anaconda\envs\Phelma1\lib\site-packages\scanpy\tools\_rank_genes_groups.py:484: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, "logfoldchanges"] = np.log2(

# %%
for disease in disease_groups:
    sub = de_by_disease[de_by_disease["disease_group"] == disease]
    print(disease)
    print("raw p < 0.05:", (sub["pvals"] < 0.05).sum())
    print("adj p < 0.05:", (sub["pvals_adj"] < 0.05).sum())
# Out:
# FSHD1
# raw p < 0.05: 2355
# adj p < 0.05: 32
# FSHD2
# raw p < 0.05: 1672
# adj p < 0.05: 130

# %%
# Create clean gene ID column
de_by_disease["gene_id_clean"] = (
    de_by_disease["gene_id"]
    .astype(str)
    .str.strip()
    .str.replace(r"\.\d+$", "", regex=True)
)

# %%
# Create significant gene sets for each disease group
# adj P < 0.05 and logFC > 1
sig_gene_sets = {}

for disease in ["FSHD1", "FSHD2"]:
    genes = set(
        de_by_disease.loc[
            (de_by_disease["disease_group"] == disease) &
            (de_by_disease["pvals_adj"] < 0.05) &
            (de_by_disease["logfoldchanges"].abs() > 1),
            "gene_id_clean"
        ].dropna()
    )
    
    sig_gene_sets[disease] = genes

for disease, genes in sig_gene_sets.items():
    print(disease, len(genes))
# Out:
# FSHD1 32
# FSHD2 123

# %%
# Define disease-specific and common genes
fshd1_specific = sig_gene_sets["FSHD1"] - sig_gene_sets["FSHD2"]
fshd2_specific = sig_gene_sets["FSHD2"] - sig_gene_sets["FSHD1"]
common_genes = sig_gene_sets["FSHD1"] & sig_gene_sets["FSHD2"]

print("FSHD1 significant:", len(sig_gene_sets["FSHD1"]))
print("FSHD2 significant:", len(sig_gene_sets["FSHD2"]))
print("FSHD1-specific:", len(fshd1_specific))
print("FSHD2-specific:", len(fshd2_specific))
print("Common:", len(common_genes))
# Out:
# FSHD1 significant: 32
# FSHD2 significant: 123
# FSHD1-specific: 13
# FSHD2-specific: 104
# Common: 19

# %%
# Annotate FSHD1-specific and FSHD2-specific gene sets
fshd1_specific_df = annotate_gene_set(
    fshd1_specific,
    id_to_symbol,
    "FSHD1 -specific")

fshd2_specific_df = annotate_gene_set(
    fshd2_specific,
    id_to_symbol,
    "FSHD2 -specific")

common_genes_df = annotate_gene_set(
    common_genes,
    id_to_symbol,
    "Common")

# %%
# Save annotated gene sets
fshd1_specific_df.to_csv(
    "FSHD1_specific_reconstructed_with_gene_symbols.csv",
    index=False)

fshd2_specific_df.to_csv(
    "FSHD2_specific_reconstructed_with_gene_symbols.csv",
    index=False)

common_genes_df.to_csv(
    "Common_reconstructed_with_gene_symbols.csv",
    index=False)

# %% [markdown]
# # DE from norm layer

# %%
# Define disease_group = FSHD1 / FSHD2 / Control

adata_norm.obs["disease_group"] = (
    adata_norm.obs["sample_batch"]
    .astype(str)
    .map(group_map))

# DE results from norm layer
disease_groups = ["FSHD1", "FSHD2"]

de_results_norm = []

for disease in disease_groups:
    result = de_disease_group(
        adata_norm,
        disease_name= disease,
        de_layer="norm"
    )
    
    if result is not None:
        de_results_norm.append(result)

de_by_disease_norm = pd.concat(de_results_norm, ignore_index=True)
# Out:
# Sample: FSHD1
# cell_classification
# Non-affected late myocytes    1226
# DUX4-affected                   14
# Name: count, dtype: int64
#
# Sample: FSHD2
# cell_classification
# Non-affected late myocytes    923
# DUX4-affected                  13
# Name: count, dtype: int64

# %% [markdown]
# # optional: differential analysis using sample batch

# %%
# differential analysis using sample batch

# Define FSHD samples
fshd_samples = ["FSHD1.1", "FSHD1.2", "FSHD2.1", "FSHD2.2"]


de_results = []

for sample in fshd_samples:
    result = run_de_for_sample(adata_de, sample)
    if result is not None:
        de_results.append(result)

de_per_sample = pd.concat(de_results, ignore_index=True)

# %%
for sample in fshd_samples:
    sub = de_per_sample[de_per_sample["sample"] == sample]
    print(sample)
    print("raw p < 0.05:", (sub["pvals"] < 0.05).sum())
    print("adj p < 0.05:", (sub["pvals_adj"] < 0.05).sum())

# %%
#Wilcoxon Rank Sum Test; BH FDR-corrected P-value < 0.05
# Keep significant differentially expressed genes

de_per_sample_sig = de_per_sample[
    (de_per_sample["pvals_adj"] < 0.05) &
    (de_per_sample["logfoldchanges"].abs() > 1)
].copy()

# %%
# Create significant gene sets for each sample
sig_gene_sets = {}

for sample in fshd_samples:
    genes = set(
        de_per_sample_sig.loc[
            de_per_sample_sig["sample"] == sample,
            "gene_id"
        ]
    )
    sig_gene_sets[sample] = genes

# Check number of significant genes per sample
for sample, genes in sig_gene_sets.items():
    print(sample, len(genes))

# %%
# Genes significant in FSHD1 samples but not in FSHD2 samples
fshd1_specific = (
    sig_gene_sets["FSHD1.1"] |
    sig_gene_sets["FSHD1.2"]
) - (
    sig_gene_sets["FSHD2.1"] |
    sig_gene_sets["FSHD2.2"]
)

print("FSHD1-specific genes:", len(fshd1_specific))

# %%
# Genes significant in FSHD2 samples but not in FSHD1 samples
fshd2_specific = (
    sig_gene_sets["FSHD2.1"] |
    sig_gene_sets["FSHD2.2"]
) - (
    sig_gene_sets["FSHD1.1"] |
    sig_gene_sets["FSHD1.2"]
)

print("FSHD2-specific genes:", len(fshd2_specific))

# %%
# Annotate FSHD1-specific and FSHD2-specific gene sets
fshd1_specific_df = annotate_gene_set(
    fshd1_specific,
    id_to_symbol,
    "FSHD1-specific"
)

fshd2_specific_df = annotate_gene_set(
    fshd2_specific,
    id_to_symbol,
    "FSHD2-specific"
)

print(fshd1_specific_df)
print(fshd2_specific_df)

# %%
# Save annotated gene sets
fshd1_specific_df.to_csv(
    "FSHD1_specific_reconstructed_with_gene_symbols.csv",
    index=False
)

fshd2_specific_df.to_csv(
    "FSHD2_specific_reconstructed_with_gene_symbols.csv",
    index=False
)

# %% [markdown]
# # volcano plot

# %%
# transfer gene_id to gene_sympol

# Add gene symbols to DE result
de_by_disease["gene_id_clean"] = (
    de_by_disease["gene_id"]
    .astype(str)
    .str.strip()
    .str.replace(r"\.\d+$", "", regex=True)
)

de_by_disease["gene_symbol"] = de_by_disease["gene_id_clean"].map(id_to_symbol)

# Use gene_id as backup if gene symbol is missing
de_by_disease["gene_label"] = de_by_disease["gene_symbol"].fillna(
    de_by_disease["gene_id"]
)

# Add gene symbols to adata.var
adata_de.var["ensembl_id_clean"] = (
    adata_de.var["ensembl_id"]
    .astype(str)
    .str.strip()
    .str.replace(r"\.\d+$", "", regex=True)
)

adata_de.var["gene_symbol"] = adata_de.var["ensembl_id_clean"].map(id_to_symbol)
adata_de.var["gene_label"] = adata_de.var["gene_symbol"].fillna(
    adata_de.var["ensembl_id"]
)

# %%
# volcano plots for each sample

for disease in disease_groups:
    sub = de_by_disease[
        de_by_disease["disease_group"] == disease
    ].copy()


    sub_filter = sub.copy()
    # Calculate -log10 adjusted p-value
    sub_filter["minus_log10_padj"] = -np.log10(
    sub_filter["pvals_adj"].replace(0, 1e-300))

    # Keep only points with -log10 adjusted p-value >= 0.5
    sub_filter = sub_filter[
    sub_filter["minus_log10_padj"] >= 0.9].copy()
    

    # number of significant genes
    print(disease, "DE genes:", sub.shape[0])
    print("Significant genes:", ((sub["pvals_adj"] < 0.05) & (sub["logfoldchanges"].abs() > 1)).sum())
    
    if sub.shape[0] == 0:
        print(disease, "has no DE result, skipped.")
        continue

    #plot
    plot_volcano(
        sub_filter,
        title=f"{disease}: DUX4-affected vs non-affected late myocytes",
        gene_col="gene_symbol",
        padj_cutoff=0.05,
        logfc_cutoff=1)
# Out:
# FSHD1 DE genes: 21460
# Significant genes: 32
# FSHD2 DE genes: 21460
# Significant genes: 123

# %% [markdown]
# # volcano using norm data

# %%
 #transfer gene_id to gene_sympol

# Add gene symbols to DE result
de_by_disease_norm["gene_id_clean"] = (
    de_by_disease_norm["gene_id"]
    .astype(str)
    .str.strip()
    .str.replace(r"\.\d+$", "", regex=True)
)

de_by_disease_norm["gene_symbol"] = de_by_disease_norm["gene_id_clean"].map(id_to_symbol)

# Use gene_id as backup if gene symbol is missing
de_by_disease_norm["gene_label"] = de_by_disease_norm["gene_symbol"].fillna(
    de_by_disease_norm["gene_id"]
)

# Add gene symbols to adata.var
adata_norm.var["ensembl_id_clean"] = (
    adata_norm.var["ensembl_id"]
    .astype(str)
    .str.strip()
    .str.replace(r"\.\d+$", "", regex=True)
)

adata_norm.var["gene_symbol"] = adata_norm.var["ensembl_id_clean"].map(id_to_symbol)
adata_norm.var["gene_label"] = adata_norm.var["gene_symbol"].fillna(
    adata_norm.var["ensembl_id"]
)

# %%
# volcano plots for each sample

for disease in disease_groups:
    sub = de_by_disease_norm[
        de_by_disease_norm["disease_group"] == disease
    ].copy()
    
    # number of significant genes
    print(disease, "DE genes:", sub.shape[0])
    print("Significant genes:", ((sub["pvals_adj"] < 0.05) & (sub["logfoldchanges"].abs() > 1)).sum())
    
    if sub.shape[0] == 0:
        print(disease, "has no DE result, skipped.")
        continue
    
    #plot
    plot_volcano(
        sub,
        title=f"{disease}: DUX4-affected vs non-affected late myocytes",
        gene_col="gene_symbol",
        padj_cutoff=0.05,
        logfc_cutoff=1)
# Out:
# FSHD1 DE genes: 21460
# Significant genes: 24
# FSHD2 DE genes: 21460
# Significant genes: 89

# %% [markdown]
# # heat map

# %%
top_gene_summary = []
top_genes = []
top_genes_by_disease = {}
top_up_genes = []
top_down_genes = []


for disease in disease_groups: 

    # Significant upregulated genes
    up = de_by_disease[
        (de_by_disease["disease_group"] == disease) &
        (de_by_disease["pvals_adj"] < 0.05) &
        (de_by_disease["logfoldchanges"] > 1)
    ].copy()
    
    up = up.sort_values("logfoldchanges", ascending=False)
    selected_up = up["gene_id_clean"].head(10).tolist()
    
    
    # Significant downregulated genes
    down = de_by_disease[
        (de_by_disease["disease_group"] == disease) &
        (de_by_disease["pvals_adj"] < 0.05) &
        (de_by_disease["logfoldchanges"] < -1)
    ].copy()
    
    down = down.sort_values("logfoldchanges", ascending=True)
    selected_down = down["gene_id_clean"].head(10).tolist()
    

    # Store up and down genes separately
    top_up_genes.extend(selected_up)
    top_down_genes.extend(selected_down)
    
    # Add to final heatmap gene list
    top_genes.extend(selected_up)
    top_genes.extend(selected_down)
    
    top_gene_summary.append({
        "disease": disease,
        "upregulated_selected": len(selected_up),
        "downregulated_selected": len(selected_down),
        "total_selected": len(selected_up) + len(selected_down)})

# Remove duplicated genes after collecting all genes
top_genes = list(dict.fromkeys(top_genes))

# order: upregulated genes first, downregulated genes second
top_genes = top_up_genes + [g for g in top_down_genes if g not in top_up_genes]

top_gene_summary_df = pd.DataFrame(top_gene_summary)
print(top_gene_summary_df)
# Out:
#   disease  upregulated_selected  downregulated_selected  total_selected
# 0   FSHD1                    10                       4              14
# 1   FSHD2                    10                      10              20

# %%
# Build mapping: clean Ensembl ID -> adata var_name
id_to_varname = dict(zip(
    adata_de.var["ensembl_id_clean"],
    adata_de.var_names
))

# Convert selected gene IDs to var_names used by adata
top_var_names = [
    id_to_varname[g]
    for g in top_genes
    if g in id_to_varname
]

# %%
# Keep FSHD samples and two cell classes
adata_heat = adata_de[
    (adata_de.obs["disease_group"].isin([
        "FSHD1", "FSHD2"
    ])) &
    (adata_de.obs["cell_classification"].isin([
        "DUX4-affected",
        "Non-affected late myocytes"
    ]))
].copy()

# Use combat-corrected data
adata_heat.X = adata_heat.layers["combat"].copy()

# Create sample + cell class group
adata_heat.obs["sample_cell_class"] = (
    adata_heat.obs["sample_batch"].astype(str)
    + " | "
    + adata_heat.obs["cell_classification"].astype(str)
)

# %%
# Create short sample labels
adata_heat.obs["sample_short"] = (
    adata_heat.obs["sample_batch"]
    .astype(str)
    .str.replace("FSHD", "", regex=False)
)

# Create short class labels
class_map = {
    "DUX4-affected": "A",
    "Non-affected late myocytes": "B"
}

adata_heat.obs["class_short"] = (
    adata_heat.obs["cell_classification"]
    .map(class_map)
)

# Create heatmap column labels
adata_heat.obs["heat_group"] = (
    adata_heat.obs["sample_short"].astype(str)
    + "-"
    + adata_heat.obs["class_short"].astype(str)
)

# Define column order
group_order = [
    "1.1-A", "1.2-A", "2.1-A","2.2-A",
    "1.1-B","1.2-B","2.1-B","2.2-B"]

# Keep only groups that exist
group_order = [
    g for g in group_order
    if g in adata_heat.obs["heat_group"].unique()
]

adata_heat.obs["heat_group"] = pd.Categorical(
    adata_heat.obs["heat_group"],
    categories=group_order,
    ordered=True
)

print(adata_heat.obs["heat_group"].value_counts())
# Out:
# heat_group
# 1.1-B    725
# 2.1-B    569
# 1.2-B    501
# 2.2-B    354
# 1.1-A     12
# 2.1-A     11
# 2.2-A      2
# 1.2-A      2
# Name: count, dtype: int64

# %%
# Extract combat version expression of selected genes
X = adata_heat[:, top_var_names].layers["combat"]

if sparse.issparse(X):
    X = X.toarray()

# Create expression dataframe
expr_df = pd.DataFrame(
    X,
    index=adata_heat.obs_names,
    columns=top_var_names
)

# Add group information
expr_df["heat_group"] = adata_heat.obs["heat_group"].values

# Calculate average expression per group
mean_expr = (
    expr_df
    .groupby("heat_group", observed=True)
    .mean()
    .T
)

# Reorder columns
mean_expr = mean_expr[group_order]

# %%
# Z-score scaling per gene
heat_data = mean_expr.sub(mean_expr.mean(axis=1), axis=0)
heat_data = heat_data.div(mean_expr.std(axis=1).replace(0, np.nan), axis=0)

# Replace NaN caused by zero standard deviation
heat_data = heat_data.fillna(0)

# Limit extreme values for clearer colors
heat_data = heat_data.clip(-1.5, 1.5)

# %%
# Add gene symbol labels
if "gene_symbol" not in adata_heat.var.columns:
    adata_heat.var["ensembl_id_clean"] = (
        adata_heat.var_names
        .astype(str)
        .str.replace('"', '', regex=False)
        .str.strip()
        .str.replace(r"\.\d+$", "", regex=True)
    )
    adata_heat.var["gene_symbol"] = (
        adata_heat.var["ensembl_id_clean"].map(id_to_symbol)
    )

# Create label map
gene_label_map = (
    adata_heat.var["gene_symbol"]
    .fillna(pd.Series(adata_heat.var_names, index=adata_heat.var_names))
    .to_dict()
)

# Replace ENSG index by gene symbols
gene_labels = [
    gene_label_map.get(g, g)
    for g in heat_data.index
]

heat_data.index = gene_labels

# %%
# Plot heatmap: genes as rows, samples/groups as columns
fig_height = max(5, 0.35 * heat_data.shape[0])
fig_width = max(7, 0.7 * heat_data.shape[1])

plt.figure(figsize=(fig_width, fig_height))

plt.imshow(
    heat_data.values,
    aspect="auto",
    cmap="bwr",
    vmin=-1.5,
    vmax=1.5
)

plt.colorbar(label="Scaled expression")

plt.xticks(
    ticks=np.arange(heat_data.shape[1]),
    labels=heat_data.columns,
    rotation=45,
    ha="right"
)

plt.yticks(
    ticks=np.arange(heat_data.shape[0]),
    labels=heat_data.index
)

plt.xlabel("Sample group(A for DUX4-effected sample, B for non-affected late myocytes)")
plt.ylabel("Gene")
plt.title("Top differentially expressed genes in DUX4-affected cells vs non-affected late myocytes")

plt.tight_layout()
plt.show()

# %% [markdown]
# # venn plot

# %%
plt.figure(figsize=(5, 5))

venn2(
    subsets=(
        sig_gene_sets["FSHD1"],
        sig_gene_sets["FSHD2"]),

    set_labels=("FSHD1", "FSHD2"),
    set_colors=("steelblue", "royalblue"),
    alpha=0.6
)

plt.title("specific genes: FSHD1 vs FSHD2")
plt.show()
